# %% [markdown]
# ### VAE to make pictures smile more
# Model wasn't trained, so this code file contains mostly helper functions

# %%
import torch 
import torchvision 
import torch.nn as nn 
import matplotlib.pyplot as plt 
import numpy as np 

from helper_data import get_dataloaders_celeba

# %%
RANDOM_SEED = 123
BATCH_SIZE = 5000
DEVICE= torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
custom_transforms= torchvision.transforms.Compose(
    [
        torchvision.transforms.CenterCrop((128,128)), # crop the center to 128x128 pixels
        torchvision.transforms.ToTensor()   # transform all the image pixels into [0,1]
    ]
)

train_loader, valid_loader, test_loader = get_dataloaders_celeba(
    batch_size=BATCH_SIZE,
    train_transforms=custom_transforms,
    test_transforms=custom_transforms,
    num_workers=2)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM
# From (redirected): https://drive.usercontent.google.com/download?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM&confirm=t&uuid=2718d3f3-7d84-4258-8269-23c38ad4e691
# To: /Users/xiang/Desktop/DL_ML_Implementations/autoencoders/data/celeba/img_align_celeba.zip
#   4%|▎         | 52.4M/1.44G [00:05<02:08, 10.8MB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       1 custom_transforms= torchvision.transforms.Compose(
#       2     [
#       3         torchvision.transforms.CenterCrop((128,128)), # crop the center to 128x128 pixels
#       4         torchvision.transforms.ToTensor()   # transform all the image pixels into [0,1]
#       5     ]
#       6 )
# ----> 8 train_loader, valid_loader, test_loader = get_dataloaders_celeba(
#       9     batch_size=BATCH_SIZE,
# ...
